# %% [markdown]
# # Lab 8: Pretrained Networks and Autoencoders
# ## 1. Model Downloading
#
# Download one of the [availiable in pytorch pretrained neural nets](https://pytorch.org/vision/stable/models.html). And print its structure. Help:
#
# ```python
# import torch, torchvision, os
# import numpy as np
# net = torchvision.models.NAME_OF_THE_MODEL(pretrained=True)
# net
# ```

# %%
# place for code
import torch, torchvision, os
import numpy as np
net = torchvision.models.resnet18(pretrained=True)
net
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# ## 2. Change Net Structure
#
# Replace the last fully connected layer by the linear layer same number of inputs (net.fc.in_features) and with 2 outputs

# %%
# place for code
net.fc = torch.nn.Linear(in_features= net.fc.in_features, out_features = 2)

# %% [markdown]
# ## 3. Define normalization and augmentation transformations for data
#
# Help:
# ```python
# data_transforms = torchvision.transforms.Compose([
#         torchvision.transforms.RandomResizedCrop(224),
#         torchvision.transforms.RandomHorizontalFlip(),
#         torchvision.transforms.ToTensor(),
#         torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#     ])
# image_dataset = torchvision.datasets.ImageFolder('data/hymenoptera/train', data_transforms)
# dataloader = torch.utils.data.DataLoader(image_dataset, batch_size=4, shuffle=True, num_workers=4)
# class_names = image_dataset.classes
# ```

# %%
# place for code
data_transforms = torchvision.transforms.Compose([
        torchvision.transforms.RandomResizedCrop(224),
        torchvision.transforms.RandomHorizontalFlip(),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
image_dataset = torchvision.datasets.ImageFolder('data/hymenoptera/train', data_transforms)
dataloader = torch.utils.data.DataLoader(image_dataset, batch_size=4, shuffle=True, num_workers=4)
class_names = image_dataset.classes

# %% [markdown]
# ## 4. Define optimization options: criterion and optimizer

# %%
# place for code
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum = 0.9)

# %% [markdown]
# ## 5. Training
#
# Copy training cycle from previous laboratory work. Along with crossentropy loss calculate and print every **10** cycles mean accuracy. Help:
#
# ```python
# predictions = np.argmax(outputs.data, axis=1)
# batch_accuracy = torch.sum(predictions == labels.data)/len(predictions)
# mean_accuracy = 0.99*mean_accuracy + 0.01*batch_accuracy
# ```

# %%
# place for code
mean_accuracy = 0.0
for epoch in range(1000):
    for cycle, data_batch in enumerate(dataloader):
        x_batch, label_batch = data_batch
        # forward step
        output = net(x_batch)
        
        # calculate loss
        loss = criterion(output, label_batch)
        
        # calculate gradients
        optimizer.zero_grad()
        loss.backward()
        
        # change weights
        optimizer.step()

        predictions = np.argmax(output.data, axis=1)
        batch_accuracy = torch.sum(predictions == label_batch.data)/len(predictions)
        mean_accuracy = 0.99*mean_accuracy + 0.01*batch_accuracy
        if cycle % 10 ==0: 
            print(f'epoch = {epoch},cycle={cycle}, mean_accuracy={mean_accuracy}')
    if mean_accuracy >= 1 - 0.098:
        break
print('finishid')
# Out:
# epoch = 0,cycle=0, mean_accuracy=0.009999999776482582
# epoch = 0,cycle=10, mean_accuracy=0.08553960919380188
# epoch = 0,cycle=20, mean_accuracy=0.1706009805202484
# epoch = 0,cycle=30, mean_accuracy=0.23549115657806396
# epoch = 0,cycle=40, mean_accuracy=0.3038100004196167
# epoch = 0,cycle=50, mean_accuracy=0.36326950788497925
# epoch = 0,cycle=60, mean_accuracy=0.41017061471939087
# epoch = 1,cycle=0, mean_accuracy=0.4160689115524292
# epoch = 1,cycle=10, mean_accuracy=0.4576133191585541
# epoch = 1,cycle=20, mean_accuracy=0.4976305663585663
# epoch = 1,cycle=30, mean_accuracy=0.5290653109550476
# epoch = 1,cycle=40, mean_accuracy=0.5508134365081787
# epoch = 1,cycle=50, mean_accuracy=0.5796404480934143
# epoch = 1,cycle=60, mean_accuracy=0.6077276468276978
# epoch = 2,cycle=0, mean_accuracy=0.6116503477096558
# epoch = 2,cycle=10, mean_accuracy=0.6463085412979126
# epoch = 2,cycle=20, mean_accuracy=0.6658352613449097
# epoch = 2,cycle=30, mean_accuracy=0.6763833165168762
# epoch = 2,cycle=40, mean_accuracy=0.7049731016159058
# epoch = 2,cycle=50, mean_accuracy=0.7234278917312622
# epoch = 2,cycle=60, mean_accuracy=0.7424479722976685
# epoch = 3,cycle=0, mean_accuracy=0.7450234889984131
# epoch = 3,cycle=10, mean_accuracy=0.7623628973960876
# epoch = 3,cycle=20, mean_accuracy=0.7685769200325012
# epoch = 3,cycle=30, mean_accuracy=0.7764589190483093
# epoch = 3,cycle=40, mean_accuracy=0.7811095714569092
# epoch = 3,cycle=50, mean_accuracy=0.7852231860160828
# epoch = 3,cycle=60, mean_accuracy=0.796366810798645
# epoch = 4,cycle=0, mean_accuracy=0.7984031438827515
# epoch = 4,cycle=10, mean_accuracy=0.7961024045944214
# epoch = 4,cycle=20, mean_accuracy=0.8063005805015564
# epoch = 4,cycle=30, mean_accuracy=0.8224680423736572
# epoch = 4,cycle=40, mean_accuracy=0.8300732374191284
# epoch = 4,cycle=50, mean_accuracy=0.8245821595191956
# epoch = 4,cycle=60, mean_accuracy=0.832127571105957
# epoch = 5,cycle=0, mean_accuracy=0.8338062763214111
# epoch = 5,cycle=10, mean_accuracy=0.8305245637893677
# epoch = 5,cycle=20, mean_accuracy=0.8321955800056458
# epoch = 5,cycle=30, mean_accuracy=0.8362058401107788
# epoch = 5,cycle=40, mean_accuracy=0.8206580281257629
# epoch = 5,cycle=50, mean_accuracy=0.8328806161880493
# epoch = 5,cycle=60, mean_accuracy=0.8344224095344543
# epoch = 6,cycle=0, mean_accuracy=0.8360781669616699
# epoch = 6,cycle=10, mean_accuracy=0.8421453237533569
# epoch = 6,cycle=20, mean_accuracy=0.8478925824165344
# epoch = 6,cycle=30, mean_accuracy=0.8530640602111816
# epoch = 6,cycle=40, mean_accuracy=0.8574337959289551
# epoch = 6,cycle=50, mean_accuracy=0.8571301698684692
# epoch = 6,cycle=60, mean_accuracy=0.8636555671691895
# epoch = 7,cycle=0, mean_accuracy=0.8625190258026123
# epoch = 7,cycle=10, mean_accuracy=0.8537259697914124
# epoch = 7,cycle=20, mean_accuracy=0.8531515598297119
# epoch = 7,cycle=30, mean_accuracy=0.8484041690826416
# epoch = 7,cycle=40, mean_accuracy=0.8486072421073914
# epoch = 7,cycle=50, mean_accuracy=0.8486896753311157
# epoch = 7,cycle=60, mean_accuracy=0.8323065042495728
# epoch = 8,cycle=0, mean_accuracy=0.8289834260940552
# epoch = 8,cycle=10, mean_accuracy=0.8092586398124695
# epoch = 8,cycle=20, mean_accuracy=0.8180336356163025
# epoch = 8,cycle=30, mean_accuracy=0.8165994882583618
# epoch = 8,cycle=40, mean_accuracy=0.821980893611908
# epoch = 8,cycle=50, mean_accuracy=0.8246127367019653
# epoch = 8,cycle=60, mean_accuracy=0.8413829207420349
# epoch = 9,cycle=0, mean_accuracy=0.8429691195487976
# epoch = 9,cycle=10, mean_accuracy=0.8487097024917603
# epoch = 9,cycle=20, mean_accuracy=0.8513070344924927
# epoch = 9,cycle=30, mean_accuracy=0.8559107780456543
# epoch = 9,cycle=40, mean_accuracy=0.8505188226699829
# epoch = 9,cycle=50, mean_accuracy=0.8623119592666626
# epoch = 9,cycle=60, mean_accuracy=0.8684619665145874
# epoch = 10,cycle=0, mean_accuracy=0.8672773241996765
# epoch = 10,cycle=10, mean_accuracy=0.865597665309906
# epoch = 10,cycle=20, mean_accuracy=0.8641040921211243
# epoch = 10,cycle=30, mean_accuracy=0.8578764200210571
# epoch = 10,cycle=40, mean_accuracy=0.857190728187561
# epoch = 10,cycle=50, mean_accuracy=0.8590023517608643
# epoch = 10,cycle=60, mean_accuracy=0.8631393313407898
# epoch = 11,cycle=0, mean_accuracy=0.8570079207420349
# epoch = 11,cycle=10, mean_accuracy=0.8682055473327637
# epoch = 11,cycle=20, mean_accuracy=0.8761221766471863
# epoch = 11,cycle=30, mean_accuracy=0.8736976981163025
# epoch = 11,cycle=40, mean_accuracy=0.8736182451248169
# epoch = 11,cycle=50, mean_accuracy=0.869129478931427
# epoch = 11,cycle=60, mean_accuracy=0.8742905259132385
# epoch = 12,cycle=0, mean_accuracy=0.8755476474761963
# epoch = 12,cycle=10, mean_accuracy=0.8711592555046082
# epoch = 12,cycle=20, mean_accuracy=0.8742047548294067
# epoch = 12,cycle=30, mean_accuracy=0.8815960884094238
# epoch = 12,cycle=40, mean_accuracy=0.8760281205177307
# epoch = 12,cycle=50, mean_accuracy=0.8855752348899841
# epoch = 12,cycle=60, mean_accuracy=0.8824097514152527
# epoch = 13,cycle=0, mean_accuracy=0.8835856318473816
# epoch = 13,cycle=10, mean_accuracy=0.8853004574775696
# epoch = 13,cycle=20, mean_accuracy=0.8867064714431763
# epoch = 13,cycle=30, mean_accuracy=0.8762026429176331
# epoch = 13,cycle=40, mean_accuracy=0.8714926838874817
# epoch = 13,cycle=50, mean_accuracy=0.8718646168708801
# epoch = 13,cycle=60, mean_accuracy=0.8626402020454407
# epoch = 14,cycle=0, mean_accuracy=0.8640137910842896
# epoch = 14,cycle=10, mean_accuracy=0.8721893429756165
# epoch = 14,cycle=20, mean_accuracy=0.8558237552642822
# epoch = 14,cycle=30, mean_accuracy=0.8575026988983154
# epoch = 14,cycle=40, mean_accuracy=0.861735463142395
# epoch = 14,cycle=50, mean_accuracy=0.8605635762214661
# epoch = 14,cycle=60, mean_accuracy=0.859408974647522
# epoch = 15,cycle=0, mean_accuracy=0.8583148717880249
# epoch = 15,cycle=10, mean_accuracy=0.8406545519828796
# epoch = 15,cycle=20, mean_accuracy=0.8419767618179321
# epoch = 15,cycle=30, mean_accuracy=0.8524254560470581
# epoch = 15,cycle=40, mean_accuracy=0.8546433448791504
# epoch = 15,cycle=50, mean_accuracy=0.8590043187141418
# epoch = 15,cycle=60, mean_accuracy=0.8677070140838623
# epoch = 16,cycle=0, mean_accuracy=0.8690299391746521
# epoch = 16,cycle=10, mean_accuracy=0.8695896863937378
# epoch = 16,cycle=20, mean_accuracy=0.8632498383522034
# epoch = 16,cycle=30, mean_accuracy=0.8668854832649231
# epoch = 16,cycle=40, mean_accuracy=0.8724283576011658
# epoch = 16,cycle=50, mean_accuracy=0.8578193187713623
# epoch = 16,cycle=60, mean_accuracy=0.8521034121513367
# epoch = 17,cycle=0, mean_accuracy=0.8535823822021484
# epoch = 17,cycle=10, mean_accuracy=0.8479030132293701
# epoch = 17,cycle=20, mean_accuracy=0.8574711680412292
# epoch = 17,cycle=30, mean_accuracy=0.863915205001831
# epoch = 17,cycle=40, mean_accuracy=0.872075617313385
# epoch = 17,cycle=50, mean_accuracy=0.8674946427345276
# epoch = 17,cycle=60, mean_accuracy=0.8706772923469543
# epoch = 18,cycle=0, mean_accuracy=0.871970534324646
# epoch = 18,cycle=10, mean_accuracy=0.8744822144508362
# epoch = 18,cycle=20, mean_accuracy=0.8817021250724792
# epoch = 18,cycle=30, mean_accuracy=0.8881620764732361
# epoch = 18,cycle=40, mean_accuracy=0.8895115256309509
# epoch = 18,cycle=50, mean_accuracy=0.8930368423461914
# epoch = 18,cycle=60, mean_accuracy=0.8843526244163513
# epoch = 19,cycle=0, mean_accuracy=0.8830090761184692
# epoch = 19,cycle=10, mean_accuracy=0.8820858597755432
# epoch = 19,cycle=20, mean_accuracy=0.8813967704772949
# epoch = 19,cycle=30, mean_accuracy=0.8927372694015503
# epoch = 19,cycle=40, mean_accuracy=0.8937192559242249
# epoch = 19,cycle=50, mean_accuracy=0.9015747308731079
# epoch = 19,cycle=60, mean_accuracy=0.903730571269989
# finishid

# %% [markdown]
# ## 6. Finetuning
#
# Try several different configurations and write here training statistics after 10 epochs for
#
# * Pretrained network (pretrained=True)
# * Not pretrained network (pretrained=False)
# * Another learning rate value
# * Using scheduler (call scheduler.step() each epoch)
# * Freeze weights of several layers of pretrained network
#
# Help:
# ```python
# # Construct a scheduler to decay LR by a factor of 0.1 every 5 epochs
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
#
# # Freeze first 7 layers:
# for i, child in enumerate(net.children()):
#     if i < 7:
#         for param in child.parameters():
#             param.requires_grad = False
# ```

# %%
# Pretrained network (pretrained=True)
pretrained_net = torchvision.models.resnet18(pretrained=True)
pretrained_net.fc = torch.nn.Linear(in_features= pretrained_net.fc.in_features, out_features = 2)
optimizer1 = torch.optim.SGD(net.parameters(), lr=0.001, momentum = 0.9)

mean_accuracy = 0.0
for epoch in range(10):
    for cycle, data_batch in enumerate(dataloader):
        x_batch, label_batch = data_batch
        output = pretrained_net(x_batch)
        loss = criterion(output, label_batch)
        optimizer1.zero_grad()
        loss.backward()
        optimizer1.step()
        predictions = np.argmax(output.data, axis=1)
        batch_accuracy = torch.sum(predictions == label_batch.data)/len(predictions)
        mean_accuracy = 0.99*mean_accuracy + 0.01*batch_accuracy
        if cycle % 10 ==0: 
            print(f'epoch = {epoch},cycle={cycle}, mean_accuracy={mean_accuracy}')
# Out:
# epoch = 0,cycle=0, mean_accuracy=0.004999999888241291
# epoch = 0,cycle=10, mean_accuracy=0.09552611410617828
# epoch = 0,cycle=20, mean_accuracy=0.172207772731781
# epoch = 0,cycle=30, mean_accuracy=0.24162867665290833
# epoch = 0,cycle=40, mean_accuracy=0.3118587136268616
# epoch = 0,cycle=50, mean_accuracy=0.3728286325931549
# epoch = 0,cycle=60, mean_accuracy=0.4234229624271393
# epoch = 1,cycle=0, mean_accuracy=0.42918872833251953
# epoch = 1,cycle=10, mean_accuracy=0.4692353308200836
# epoch = 1,cycle=20, mean_accuracy=0.5008914470672607
# epoch = 1,cycle=30, mean_accuracy=0.5390811562538147
# epoch = 1,cycle=40, mean_accuracy=0.5784927010536194
# epoch = 1,cycle=50, mean_accuracy=0.6116379499435425
# epoch = 1,cycle=60, mean_accuracy=0.6440406441688538
# epoch = 2,cycle=0, mean_accuracy=0.6451002359390259
# epoch = 2,cycle=10, mean_accuracy=0.6577988862991333
# epoch = 2,cycle=20, mean_accuracy=0.6810281872749329
# epoch = 2,cycle=30, mean_accuracy=0.6994459629058838
# epoch = 2,cycle=40, mean_accuracy=0.7210751175880432
# epoch = 2,cycle=50, mean_accuracy=0.7404664754867554
# epoch = 2,cycle=60, mean_accuracy=0.7606221437454224
# epoch = 3,cycle=0, mean_accuracy=0.7630159258842468
# epoch = 3,cycle=10, mean_accuracy=0.7738056182861328
# epoch = 3,cycle=20, mean_accuracy=0.7766239643096924
# epoch = 3,cycle=30, mean_accuracy=0.7835676670074463
# epoch = 3,cycle=40, mean_accuracy=0.7947999238967896
# epoch = 3,cycle=50, mean_accuracy=0.8097130656242371
# epoch = 3,cycle=60, mean_accuracy=0.8136845827102661
# epoch = 4,cycle=0, mean_accuracy=0.8155477643013
# epoch = 4,cycle=10, mean_accuracy=0.8211272358894348
# epoch = 4,cycle=20, mean_accuracy=0.8238844275474548
# epoch = 4,cycle=30, mean_accuracy=0.8335418105125427
# epoch = 4,cycle=40, mean_accuracy=0.832643449306488
# epoch = 4,cycle=50, mean_accuracy=0.8416081070899963
# epoch = 4,cycle=60, mean_accuracy=0.8396676778793335
# epoch = 5,cycle=0, mean_accuracy=0.8337709903717041
# epoch = 5,cycle=10, mean_accuracy=0.8325563669204712
# epoch = 5,cycle=20, mean_accuracy=0.8415520787239075
# epoch = 5,cycle=30, mean_accuracy=0.8398163318634033
# epoch = 5,cycle=40, mean_accuracy=0.8455438017845154
# epoch = 5,cycle=50, mean_accuracy=0.8554109930992126
# epoch = 5,cycle=60, mean_accuracy=0.8524155020713806
# epoch = 6,cycle=0, mean_accuracy=0.8538913726806641
# epoch = 6,cycle=10, mean_accuracy=0.8655318021774292
# epoch = 6,cycle=20, mean_accuracy=0.8598875403404236
# epoch = 6,cycle=30, mean_accuracy=0.8564923405647278
# epoch = 6,cycle=40, mean_accuracy=0.8678367137908936
# epoch = 6,cycle=50, mean_accuracy=0.8662517666816711
# epoch = 6,cycle=60, mean_accuracy=0.8622232675552368
# epoch = 7,cycle=0, mean_accuracy=0.8586010336875916
# epoch = 7,cycle=10, mean_accuracy=0.8674359917640686
# epoch = 7,cycle=20, mean_accuracy=0.8612560033798218
# epoch = 7,cycle=30, mean_accuracy=0.8478816747665405
# epoch = 7,cycle=40, mean_accuracy=0.8529875874519348
# epoch = 7,cycle=50, mean_accuracy=0.8645944595336914
# epoch = 7,cycle=60, mean_accuracy=0.8701656460762024
# epoch = 8,cycle=0, mean_accuracy=0.8714640140533447
# epoch = 8,cycle=10, mean_accuracy=0.8790470361709595
# epoch = 8,cycle=20, mean_accuracy=0.8834062218666077
# epoch = 8,cycle=30, mean_accuracy=0.8898230791091919
# epoch = 8,cycle=40, mean_accuracy=0.8909186720848083
# epoch = 8,cycle=50, mean_accuracy=0.8941412568092346
# epoch = 8,cycle=60, mean_accuracy=0.8880199790000916
# epoch = 9,cycle=0, mean_accuracy=0.8816397786140442
# epoch = 9,cycle=10, mean_accuracy=0.880993664264679
# epoch = 9,cycle=20, mean_accuracy=0.8831198811531067
# epoch = 9,cycle=30, mean_accuracy=0.8749818801879883
# epoch = 9,cycle=40, mean_accuracy=0.8748968839645386
# epoch = 9,cycle=50, mean_accuracy=0.8843590021133423
# epoch = 9,cycle=60, mean_accuracy=0.8882108926773071

# %%
# Not pretrained network (pretrained=False)
not_pretrained_net = torchvision.models.resnet18(pretrained=False)
not_pretrained_net.fc = torch.nn.Linear(in_features= not_pretrained_net.fc.in_features, out_features = 2)
optimizer2 = torch.optim.SGD(net.parameters(), lr=0.001, momentum = 0.9)

mean_accuracy = 0.0
for epoch in range(10):
    for cycle, data_batch in enumerate(dataloader):
        x_batch, label_batch = data_batch
        output = not_pretrained_net(x_batch)
        loss = criterion(output, label_batch)
        optimizer2.zero_grad()
        loss.backward()
        optimizer2.step()
        predictions = np.argmax(output.data, axis=1)
        batch_accuracy = torch.sum(predictions == label_batch.data)/len(predictions)
        mean_accuracy = 0.99*mean_accuracy + 0.01*batch_accuracy
        if cycle % 10 ==0: 
            print(f'epoch = {epoch},cycle={cycle}, mean_accuracy={mean_accuracy}')
# Out:
# epoch = 0,cycle=0, mean_accuracy=0.0024999999441206455
# epoch = 0,cycle=10, mean_accuracy=0.04552849382162094
# epoch = 0,cycle=20, mean_accuracy=0.08908043056726456
# epoch = 0,cycle=30, mean_accuracy=0.13038983941078186
# epoch = 0,cycle=40, mean_accuracy=0.17063170671463013
# epoch = 0,cycle=50, mean_accuracy=0.19744037091732025
# epoch = 0,cycle=60, mean_accuracy=0.23346015810966492
# epoch = 1,cycle=0, mean_accuracy=0.23112556338310242
# epoch = 1,cycle=10, mean_accuracy=0.26663628220558167
# epoch = 1,cycle=20, mean_accuracy=0.28897398710250854
# epoch = 1,cycle=30, mean_accuracy=0.302473247051239
# epoch = 1,cycle=40, mean_accuracy=0.3284672796726227
# epoch = 1,cycle=50, mean_accuracy=0.3399876058101654
# epoch = 1,cycle=60, mean_accuracy=0.3576405644416809
# epoch = 2,cycle=0, mean_accuracy=0.35906416177749634
# epoch = 2,cycle=10, mean_accuracy=0.36540719866752625
# epoch = 2,cycle=20, mean_accuracy=0.3805555999279022
# epoch = 2,cycle=30, mean_accuracy=0.40653741359710693
# epoch = 2,cycle=40, mean_accuracy=0.4129296839237213
# epoch = 2,cycle=50, mean_accuracy=0.41866227984428406
# epoch = 2,cycle=60, mean_accuracy=0.4238438010215759
# epoch = 3,cycle=0, mean_accuracy=0.4246053695678711
# epoch = 3,cycle=10, mean_accuracy=0.43161866068840027
# epoch = 3,cycle=20, mean_accuracy=0.433371901512146
# epoch = 3,cycle=30, mean_accuracy=0.4372437298297882
# epoch = 3,cycle=40, mean_accuracy=0.4381251931190491
# epoch = 3,cycle=50, mean_accuracy=0.45146653056144714
# epoch = 3,cycle=60, mean_accuracy=0.46288561820983887
# epoch = 4,cycle=0, mean_accuracy=0.460756778717041
# epoch = 4,cycle=10, mean_accuracy=0.46203672885894775
# epoch = 4,cycle=20, mean_accuracy=0.46595442295074463
# epoch = 4,cycle=30, mean_accuracy=0.4696928858757019
# epoch = 4,cycle=40, mean_accuracy=0.47189226746559143
# epoch = 4,cycle=50, mean_accuracy=0.472204327583313
# epoch = 4,cycle=60, mean_accuracy=0.4847102463245392
# epoch = 5,cycle=0, mean_accuracy=0.48486313223838806
# epoch = 5,cycle=10, mean_accuracy=0.4861697256565094
# epoch = 5,cycle=20, mean_accuracy=0.48742586374282837
# epoch = 5,cycle=30, mean_accuracy=0.4838475286960602
# epoch = 5,cycle=40, mean_accuracy=0.48058998584747314
# epoch = 5,cycle=50, mean_accuracy=0.49912258982658386
# epoch = 5,cycle=60, mean_accuracy=0.49444785714149475
# epoch = 6,cycle=0, mean_accuracy=0.49700337648391724
# epoch = 6,cycle=10, mean_accuracy=0.5021440982818604
# epoch = 6,cycle=20, mean_accuracy=0.5112914443016052
# epoch = 6,cycle=30, mean_accuracy=0.5128277540206909
# epoch = 6,cycle=40, mean_accuracy=0.5048744082450867
# epoch = 6,cycle=50, mean_accuracy=0.5044302940368652
# epoch = 6,cycle=60, mean_accuracy=0.4945145845413208
# epoch = 7,cycle=0, mean_accuracy=0.49206945300102234
# epoch = 7,cycle=10, mean_accuracy=0.4856671392917633
# epoch = 7,cycle=20, mean_accuracy=0.49864134192466736
# epoch = 7,cycle=30, mean_accuracy=0.4961286187171936
# epoch = 7,cycle=40, mean_accuracy=0.5015230774879456
# epoch = 7,cycle=50, mean_accuracy=0.49157944321632385
# epoch = 7,cycle=60, mean_accuracy=0.4995165169239044
# epoch = 8,cycle=0, mean_accuracy=0.497021347284317
# epoch = 8,cycle=10, mean_accuracy=0.5115976929664612
# epoch = 8,cycle=20, mean_accuracy=0.5132474303245544
# epoch = 8,cycle=30, mean_accuracy=0.5047268271446228
# epoch = 8,cycle=40, mean_accuracy=0.4998096525669098
# epoch = 8,cycle=50, mean_accuracy=0.5070597529411316
# epoch = 8,cycle=60, mean_accuracy=0.49973103404045105
# epoch = 9,cycle=0, mean_accuracy=0.49723371863365173
# epoch = 9,cycle=10, mean_accuracy=0.4953109622001648
# epoch = 9,cycle=20, mean_accuracy=0.4908367097377777
# epoch = 9,cycle=30, mean_accuracy=0.4989200234413147
# epoch = 9,cycle=40, mean_accuracy=0.49160146713256836
# epoch = 9,cycle=50, mean_accuracy=0.4878885746002197
# epoch = 9,cycle=60, mean_accuracy=0.5055774450302124

# %%
# Another learning rate value
pretrained_net = torchvision.models.resnet18(pretrained=True)
pretrained_net.fc = torch.nn.Linear(in_features= pretrained_net.fc.in_features, out_features = 2)
optimizer3 = torch.optim.SGD(net.parameters(), lr=0.009, momentum = 0.9)

mean_accuracy = 0.0
for epoch in range(10):
    for cycle, data_batch in enumerate(dataloader):
        x_batch, label_batch = data_batch
        output = pretrained_net(x_batch)
        loss = criterion(output, label_batch)
        optimizer3.zero_grad()
        loss.backward()
        optimizer3.step()
        predictions = np.argmax(output.data, axis=1)
        batch_accuracy = torch.sum(predictions == label_batch.data)/len(predictions)
        mean_accuracy = 0.99*mean_accuracy + 0.01*batch_accuracy
        if cycle % 10 ==0: 
            print(f'epoch = {epoch},cycle={cycle}, mean_accuracy={mean_accuracy}')
# Out:
# epoch = 0,cycle=0, mean_accuracy=0.0024999999441206455
# epoch = 0,cycle=10, mean_accuracy=0.042575251311063766
# epoch = 0,cycle=20, mean_accuracy=0.07209239155054092
# epoch = 0,cycle=30, mean_accuracy=0.11070146411657333
# epoch = 0,cycle=40, mean_accuracy=0.11916866898536682
# epoch = 0,cycle=50, mean_accuracy=0.14087967574596405
# epoch = 0,cycle=60, mean_accuracy=0.17315351963043213
# epoch = 1,cycle=0, mean_accuracy=0.17392198741436005
# epoch = 1,cycle=10, mean_accuracy=0.19585300981998444
# epoch = 1,cycle=20, mean_accuracy=0.22238659858703613
# epoch = 1,cycle=30, mean_accuracy=0.22257913649082184
# epoch = 1,cycle=40, mean_accuracy=0.22755424678325653
# epoch = 1,cycle=50, mean_accuracy=0.23952741920948029
# epoch = 1,cycle=60, mean_accuracy=0.25042712688446045
# epoch = 2,cycle=0, mean_accuracy=0.250422865152359
# epoch = 2,cycle=10, mean_accuracy=0.25011733174324036
# epoch = 2,cycle=20, mean_accuracy=0.26207059621810913
# epoch = 2,cycle=30, mean_accuracy=0.26555222272872925
# epoch = 2,cycle=40, mean_accuracy=0.26915666460990906
# epoch = 2,cycle=50, mean_accuracy=0.2912514805793762
# epoch = 2,cycle=60, mean_accuracy=0.3040255606174469
# epoch = 3,cycle=0, mean_accuracy=0.30348530411720276
# epoch = 3,cycle=10, mean_accuracy=0.30773860216140747
# epoch = 3,cycle=20, mean_accuracy=0.3143989145755768
# epoch = 3,cycle=30, mean_accuracy=0.32493269443511963
# epoch = 3,cycle=40, mean_accuracy=0.3249984681606293
# epoch = 3,cycle=50, mean_accuracy=0.3322446942329407
# epoch = 3,cycle=60, mean_accuracy=0.3437916934490204
# epoch = 4,cycle=0, mean_accuracy=0.340353786945343
# epoch = 4,cycle=10, mean_accuracy=0.3509376645088196
# epoch = 4,cycle=20, mean_accuracy=0.35089871287345886
# epoch = 4,cycle=30, mean_accuracy=0.34588924050331116
# epoch = 4,cycle=40, mean_accuracy=0.3559858202934265
# epoch = 4,cycle=50, mean_accuracy=0.364665687084198
# epoch = 4,cycle=60, mean_accuracy=0.3680884838104248
# epoch = 5,cycle=0, mean_accuracy=0.36690759658813477
# epoch = 5,cycle=10, mean_accuracy=0.374880313873291
# epoch = 5,cycle=20, mean_accuracy=0.3869633674621582
# epoch = 5,cycle=30, mean_accuracy=0.380474328994751
# epoch = 5,cycle=40, mean_accuracy=0.3798697292804718
# epoch = 5,cycle=50, mean_accuracy=0.37922462821006775
# epoch = 5,cycle=60, mean_accuracy=0.36922380328178406
# epoch = 6,cycle=0, mean_accuracy=0.3705315589904785
# epoch = 6,cycle=10, mean_accuracy=0.3636704981327057
# epoch = 6,cycle=20, mean_accuracy=0.36250412464141846
# epoch = 6,cycle=30, mean_accuracy=0.35396087169647217
# epoch = 6,cycle=40, mean_accuracy=0.3490158021450043
# epoch = 6,cycle=50, mean_accuracy=0.33930912613868713
# epoch = 6,cycle=60, mean_accuracy=0.3453260362148285
# epoch = 7,cycle=0, mean_accuracy=0.34437277913093567
# epoch = 7,cycle=10, mean_accuracy=0.35004815459251404
# epoch = 7,cycle=20, mean_accuracy=0.34526264667510986
# epoch = 7,cycle=30, mean_accuracy=0.34305548667907715
# epoch = 7,cycle=40, mean_accuracy=0.35582929849624634
# epoch = 7,cycle=50, mean_accuracy=0.3648344576358795
# epoch = 7,cycle=60, mean_accuracy=0.35839608311653137
# epoch = 8,cycle=0, mean_accuracy=0.3598121106624603
# epoch = 8,cycle=10, mean_accuracy=0.3590187132358551
# epoch = 8,cycle=20, mean_accuracy=0.35817795991897583
# epoch = 8,cycle=30, mean_accuracy=0.34792813658714294
# epoch = 8,cycle=40, mean_accuracy=0.35732534527778625
# epoch = 8,cycle=50, mean_accuracy=0.35669413208961487
# epoch = 8,cycle=60, mean_accuracy=0.3559533655643463
# epoch = 9,cycle=0, mean_accuracy=0.35489383339881897
# epoch = 9,cycle=10, mean_accuracy=0.34702685475349426
# epoch = 9,cycle=20, mean_accuracy=0.3449079692363739
# epoch = 9,cycle=30, mean_accuracy=0.347721129655838
# epoch = 9,cycle=40, mean_accuracy=0.352765291929245
# epoch = 9,cycle=50, mean_accuracy=0.36232590675354004
# epoch = 9,cycle=60, mean_accuracy=0.3534396290779114

# %%
# Using scheduler (call scheduler.step() each epoch)
pretrained_net = torchvision.models.resnet18(pretrained=True)
pretrained_net.fc = torch.nn.Linear(in_features= pretrained_net.fc.in_features, out_features = 2)
optimizer4 = torch.optim.SGD(net.parameters(), lr=0.001, momentum = 0.9)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer4, step_size=5, gamma=0.1)

mean_accuracy = 0.0
for epoch in range(10):
    for cycle, data_batch in enumerate(dataloader):
        x_batch, label_batch = data_batch
        output = pretrained_net(x_batch)
        loss = criterion(output, label_batch)
        loss.backward()
        optimizer4.step()
        scheduler.step()
        predictions = np.argmax(output.data, axis=1)
        batch_accuracy = torch.sum(predictions == label_batch.data)/len(predictions)
        mean_accuracy = 0.99*mean_accuracy + 0.01*batch_accuracy
        if cycle % 10 ==0: 
            print(f'epoch = {epoch},cycle={cycle}, mean_accuracy={mean_accuracy}')
# Out:
# epoch = 0,cycle=0, mean_accuracy=0.007499999832361937
# epoch = 0,cycle=10, mean_accuracy=0.04947558417916298
# epoch = 0,cycle=20, mean_accuracy=0.10917787998914719
# epoch = 0,cycle=30, mean_accuracy=0.14166711270809174
# epoch = 0,cycle=40, mean_accuracy=0.18080973625183105
# epoch = 0,cycle=50, mean_accuracy=0.21352018415927887
# epoch = 0,cycle=60, mean_accuracy=0.23606225848197937
# epoch = 1,cycle=0, mean_accuracy=0.23870162665843964
# epoch = 1,cycle=10, mean_accuracy=0.27353763580322266
# epoch = 1,cycle=20, mean_accuracy=0.3023015558719635
# epoch = 1,cycle=30, mean_accuracy=0.30684152245521545
# epoch = 1,cycle=40, mean_accuracy=0.33009493350982666
# epoch = 1,cycle=50, mean_accuracy=0.34175071120262146
# epoch = 1,cycle=60, mean_accuracy=0.35488685965538025
# epoch = 2,cycle=0, mean_accuracy=0.3563379943370819
# epoch = 2,cycle=10, mean_accuracy=0.3797531723976135
# epoch = 2,cycle=20, mean_accuracy=0.39125433564186096
# epoch = 2,cycle=30, mean_accuracy=0.3944697678089142
# epoch = 2,cycle=40, mean_accuracy=0.39989376068115234
# epoch = 2,cycle=50, mean_accuracy=0.40243127942085266
# epoch = 2,cycle=60, mean_accuracy=0.4070288836956024
# epoch = 3,cycle=0, mean_accuracy=0.40545859932899475
# epoch = 3,cycle=10, mean_accuracy=0.4197845160961151
# epoch = 3,cycle=20, mean_accuracy=0.429617315530777
# epoch = 3,cycle=30, mean_accuracy=0.4339917004108429
# epoch = 3,cycle=40, mean_accuracy=0.4334281384944916
# epoch = 3,cycle=50, mean_accuracy=0.4471459686756134
# epoch = 3,cycle=60, mean_accuracy=0.4471549093723297
# epoch = 4,cycle=0, mean_accuracy=0.45268335938453674
# epoch = 4,cycle=10, mean_accuracy=0.46463340520858765
# epoch = 4,cycle=20, mean_accuracy=0.4728202223777771
# epoch = 4,cycle=30, mean_accuracy=0.47318652272224426
# epoch = 4,cycle=40, mean_accuracy=0.471016526222229
# epoch = 4,cycle=50, mean_accuracy=0.49089473485946655
# epoch = 4,cycle=60, mean_accuracy=0.4701653718948364
# epoch = 5,cycle=0, mean_accuracy=0.46796372532844543
# epoch = 5,cycle=10, mean_accuracy=0.468747079372406
# epoch = 5,cycle=20, mean_accuracy=0.46222150325775146
# epoch = 5,cycle=30, mean_accuracy=0.4611268937587738
# epoch = 5,cycle=40, mean_accuracy=0.4627051055431366
# epoch = 5,cycle=50, mean_accuracy=0.4613456428050995
# epoch = 5,cycle=60, mean_accuracy=0.4652866721153259
# epoch = 6,cycle=0, mean_accuracy=0.4606338143348694
# epoch = 6,cycle=10, mean_accuracy=0.4664914608001709
# epoch = 6,cycle=20, mean_accuracy=0.4599420130252838
# epoch = 6,cycle=30, mean_accuracy=0.4730958044528961
# epoch = 6,cycle=40, mean_accuracy=0.4876779317855835
# epoch = 6,cycle=50, mean_accuracy=0.4767247438430786
# epoch = 6,cycle=60, mean_accuracy=0.4718363881111145
# epoch = 7,cycle=0, mean_accuracy=0.47461801767349243
# epoch = 7,cycle=10, mean_accuracy=0.46272823214530945
# epoch = 7,cycle=20, mean_accuracy=0.46413105726242065
# epoch = 7,cycle=30, mean_accuracy=0.46998581290245056
# epoch = 7,cycle=40, mean_accuracy=0.47525739669799805
# epoch = 7,cycle=50, mean_accuracy=0.47511568665504456
# epoch = 7,cycle=60, mean_accuracy=0.4775651693344116
# epoch = 8,cycle=0, mean_accuracy=0.475289523601532
# epoch = 8,cycle=10, mean_accuracy=0.4753478467464447
# epoch = 8,cycle=20, mean_accuracy=0.47804105281829834
# epoch = 8,cycle=30, mean_accuracy=0.47492721676826477
# epoch = 8,cycle=40, mean_accuracy=0.4652652144432068
# epoch = 8,cycle=50, mean_accuracy=0.47120124101638794
# epoch = 8,cycle=60, mean_accuracy=0.4782784581184387
# epoch = 9,cycle=0, mean_accuracy=0.48099568486213684
# epoch = 9,cycle=10, mean_accuracy=0.4852374494075775
# epoch = 9,cycle=20, mean_accuracy=0.4773038923740387
# epoch = 9,cycle=30, mean_accuracy=0.47476667165756226
# epoch = 9,cycle=40, mean_accuracy=0.47708043456077576
# epoch = 9,cycle=50, mean_accuracy=0.48402687907218933
# epoch = 9,cycle=60, mean_accuracy=0.48538312315940857

# %%
# Freeze first 7 layers:
pretrained_net = torchvision.models.resnet18(pretrained=True)
pretrained_net.fc = torch.nn.Linear(in_features= pretrained_net.fc.in_features, out_features = 2)
optimizer5 = torch.optim.SGD(net.parameters(), lr=0.001, momentum = 0.9)

for i, child in enumerate(pretrained_net.children()):
    if i < 7:
        for param in child.parameters():
            param.requires_grad = False

mean_accuracy = 0.0
for epoch in range(10):
    for cycle, data_batch in enumerate(dataloader):
        x_batch, label_batch = data_batch
        output = pretrained_net(x_batch)
        loss = criterion(output, label_batch)
        optimizer5.zero_grad()
        loss.backward()
        optimizer5.step()
        predictions = np.argmax(output.data, axis=1)
        batch_accuracy = torch.sum(predictions == label_batch.data)/len(predictions)
        mean_accuracy = 0.99*mean_accuracy + 0.01*batch_accuracy
        if cycle % 10 ==0: 
            print(f'epoch = {epoch},cycle={cycle}, mean_accuracy={mean_accuracy}')
# Out:
# epoch = 0,cycle=0, mean_accuracy=0.0
# epoch = 0,cycle=10, mean_accuracy=0.054895684123039246
# epoch = 0,cycle=20, mean_accuracy=0.11412703990936279
# epoch = 0,cycle=30, mean_accuracy=0.16793307662010193
# epoch = 0,cycle=40, mean_accuracy=0.21393339335918427
# epoch = 0,cycle=50, mean_accuracy=0.2629522681236267
# epoch = 0,cycle=60, mean_accuracy=0.2907351851463318
# epoch = 1,cycle=0, mean_accuracy=0.2978278398513794
# epoch = 1,cycle=10, mean_accuracy=0.32667624950408936
# epoch = 1,cycle=20, mean_accuracy=0.3550409972667694
# epoch = 1,cycle=30, mean_accuracy=0.37586838006973267
# epoch = 1,cycle=40, mean_accuracy=0.3951149880886078
# epoch = 1,cycle=50, mean_accuracy=0.40951424837112427
# epoch = 1,cycle=60, mean_accuracy=0.4249648153781891
# epoch = 2,cycle=0, mean_accuracy=0.4257151782512665
# epoch = 2,cycle=10, mean_accuracy=0.45189782977104187
# epoch = 2,cycle=20, mean_accuracy=0.4705292582511902
# epoch = 2,cycle=30, mean_accuracy=0.48309776186943054
# epoch = 2,cycle=40, mean_accuracy=0.4917750060558319
# epoch = 2,cycle=50, mean_accuracy=0.4997444152832031
# epoch = 2,cycle=60, mean_accuracy=0.5235757827758789
# epoch = 3,cycle=0, mean_accuracy=0.5258400440216064
# epoch = 3,cycle=10, mean_accuracy=0.5306029915809631
# epoch = 3,cycle=20, mean_accuracy=0.5399776101112366
# epoch = 3,cycle=30, mean_accuracy=0.555036187171936
# epoch = 3,cycle=40, mean_accuracy=0.5592653155326843
# epoch = 3,cycle=50, mean_accuracy=0.5675349831581116
# epoch = 3,cycle=60, mean_accuracy=0.5727770924568176
# epoch = 4,cycle=0, mean_accuracy=0.5745493173599243
# epoch = 4,cycle=10, mean_accuracy=0.5772936344146729
# epoch = 4,cycle=20, mean_accuracy=0.5868645310401917
# epoch = 4,cycle=30, mean_accuracy=0.5858391523361206
# epoch = 4,cycle=40, mean_accuracy=0.568292498588562
# epoch = 4,cycle=50, mean_accuracy=0.588210940361023
# epoch = 4,cycle=60, mean_accuracy=0.5909942984580994
# epoch = 5,cycle=0, mean_accuracy=0.5900843739509583
# epoch = 5,cycle=10, mean_accuracy=0.5837512016296387
# epoch = 5,cycle=20, mean_accuracy=0.6023379564285278
# epoch = 5,cycle=30, mean_accuracy=0.5922617316246033
# epoch = 5,cycle=40, mean_accuracy=0.5883421301841736
# epoch = 5,cycle=50, mean_accuracy=0.5992586016654968
# epoch = 5,cycle=60, mean_accuracy=0.5873203277587891
# epoch = 6,cycle=0, mean_accuracy=0.5889471173286438
# epoch = 6,cycle=10, mean_accuracy=0.5903380513191223
# epoch = 6,cycle=20, mean_accuracy=0.5841983556747437
# epoch = 6,cycle=30, mean_accuracy=0.5858280062675476
# epoch = 6,cycle=40, mean_accuracy=0.5873029828071594
# epoch = 6,cycle=50, mean_accuracy=0.5933231115341187
# epoch = 6,cycle=60, mean_accuracy=0.5862506628036499
# epoch = 7,cycle=0, mean_accuracy=0.5803881883621216
# epoch = 7,cycle=10, mean_accuracy=0.5822398662567139
# epoch = 7,cycle=20, mean_accuracy=0.5791321396827698
# epoch = 7,cycle=30, mean_accuracy=0.581244945526123
# epoch = 7,cycle=40, mean_accuracy=0.5858510136604309
# epoch = 7,cycle=50, mean_accuracy=0.5916699171066284
# epoch = 7,cycle=60, mean_accuracy=0.597100555896759
# epoch = 8,cycle=0, mean_accuracy=0.5986295342445374
# epoch = 8,cycle=10, mean_accuracy=0.5988344550132751
# epoch = 8,cycle=20, mean_accuracy=0.586808979511261
# epoch = 8,cycle=30, mean_accuracy=0.5974875092506409
# epoch = 8,cycle=40, mean_accuracy=0.5882585644721985
# epoch = 8,cycle=50, mean_accuracy=0.5917358994483948
# epoch = 8,cycle=60, mean_accuracy=0.5899569988250732
# epoch = 9,cycle=0, mean_accuracy=0.5915574431419373
# epoch = 9,cycle=10, mean_accuracy=0.5903429985046387
# epoch = 9,cycle=20, mean_accuracy=0.5794690847396851
# epoch = 9,cycle=30, mean_accuracy=0.5764369964599609
# epoch = 9,cycle=40, mean_accuracy=0.5642532110214233
# epoch = 9,cycle=50, mean_accuracy=0.5702874660491943
# epoch = 9,cycle=60, mean_accuracy=0.570824146270752

# %%
# place for comments

# Pretrained network (pretrained=True) ------------- Mean Accuracy after 10 epoch: 0.8882108926773071
# Not Pretrained network (pretrained=False)  ------- Mean Accuracy after 10 epoch: 0.5055774450302124
# Another learning rate value (0.009)  ------------- Mean Accuracy after 10 epoch: 0.3534396290779114
# Using scheduler  --------------------------------- Mean Accuracy after 10 epoch: 0.48538312315940857
# Freeze first 7 layers  --------------------------- Mean Accuracy after 10 epoch: 0.570824146270752
